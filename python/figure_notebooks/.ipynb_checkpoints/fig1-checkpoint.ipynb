# %%
# - Define plot params
cmapnow = plt.cm.get_cmap('PuOr',11)

stipsizenow = 10
stipmarknow = 'o'
stipfacecolnow = 'none'
stipltdkconow = 0.6 # light/dark Pearson CC cutoff
stipedgeltcolnow = 'whitesmoke'
stipedgedkcolnow = 'black'
stipewnow = 0.8 # marker edge width

eezfcnow = 'none'
eezlcnow = 'silver'
eezlsnow = '-'
eezlwnow = 1.5

# %%
# - Set proj and define axes
fig,axes = plt.subplots(nrows=2, ncols=1, figsize=(6.7,5.2),
    subplot_kw={'projection': ccrs.PlateCarree(central_longitude=200)})

# - Make maps pretty + add panel label
for n, ax in enumerate(fig.axes):
    exec(open('helper_scripts/create_map_bgs.py').read())
    ax.text(-0.08, 1.08, string.ascii_uppercase[n], transform=ax.transAxes, 
            size=18, weight='bold') 

# - Plot bet vs. skj correl (fig. 1a)
bvss_cp_tot_cc.plot(
    ax=axes[0], transform=ccrs.PlateCarree(), cmap=cmapnow,
    cbar_kwargs={'pad': 0.02, 'label': 'Correlation coefficient'})
[ltcol_signiflonnow,ltcol_signiflatnow]=find_where_pval_small(
    bvss_cp_tot_cc_pval.where(abs(bvss_cp_tot_cc)>stipltdkconow),
    bvss_cp_tot_cc_ptf)
[dkcol_signiflonnow,dkcol_signiflatnow]=find_where_pval_small(
    bvss_cp_tot_cc_pval.where(abs(bvss_cp_tot_cc)<=stipltdkconow),
    bvss_cp_tot_cc_ptf)
axes[0].scatter(ltcol_signiflonnow, ltcol_signiflatnow,
    marker=stipmarknow, linewidths=stipewnow,
    facecolors=stipfacecolnow, edgecolors=stipedgeltcolnow,
    s=stipsizenow, transform=ccrs.PlateCarree())
axes[0].scatter(dkcol_signiflonnow, dkcol_signiflatnow,
    marker=stipmarknow, linewidths=stipewnow,
    facecolors=stipfacecolnow, edgecolors=stipedgedkcolnow,
    s=stipsizenow, transform=ccrs.PlateCarree())
axes[0].set_xlabel(''); axes[0].set_ylabel('')
axes[0].set_title('BET vs. SKJ CPUE correlation')

# - Plot b:s vs. skj correl (fig. 1b)
b2svss_cp_tot_cc.plot(
    ax=axes[1], transform=ccrs.PlateCarree(), cmap=cmapnow,
    cbar_kwargs={'pad': 0.02, 'label': 'Correlation coefficient'});
[ltcol_signiflonnow,ltcol_signiflatnow]=find_where_pval_small(
    b2svss_cp_tot_cc_pval.where(abs(b2svss_cp_tot_cc)>stipltdkconow),
    b2svss_cp_tot_cc_ptf)
[dkcol_signiflonnow,dkcol_signiflatnow]=find_where_pval_small(
    b2svss_cp_tot_cc_pval.where(abs(b2svss_cp_tot_cc)<=stipltdkconow),
    b2svss_cp_tot_cc_ptf)
axes[1].scatter(ltcol_signiflonnow, ltcol_signiflatnow,
    marker=stipmarknow, linewidths=stipewnow,
    facecolors=stipfacecolnow, edgecolors=stipedgeltcolnow,
    s=stipsizenow, transform=ccrs.PlateCarree())
axes[1].scatter(dkcol_signiflonnow, dkcol_signiflatnow,
    marker=stipmarknow, linewidths=stipewnow,
    facecolors=stipfacecolnow, edgecolors=stipedgedkcolnow,
    s=stipsizenow, transform=ccrs.PlateCarree())
axes[1].set_xlabel(''); axes[1].set_ylabel('');
axes[1].set_title('BET:SKJ vs. SKJ CPUE correlation')

# - Save fig
fig.savefig(figpath + 'Fig1.png',
            bbox_inches='tight', pad_inches = 0, dpi = 300)
fig.savefig(figpath + 'Fig1.tif',
            bbox_inches='tight', pad_inches = 0, dpi = 300,
            pil_kwargs={"compression": "tiff_lzw"})
