# %% [markdown]
# # Setup, load data, and perform some calculations

# %% [markdown]
# ### Import packages and setup options/directories

# %%
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
import datetime
import geopandas as gpd
from glob import glob
from matplotlib import cm
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.ticker as mticker
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import regionmask
#from reverse_colormap import reverse_colormap # in python dir
import scipy.stats as stats
from scipy import interpolate as spinterpolate
import warnings
import xarray as xr

# %%
# %matplotlib inline

# %%
warnings.filterwarnings('ignore')

# %%
# - See what dir we're in
os.getcwd()
# Out:
# '/opt/skipjack-bigeye-separation/python/bet_skj_separation_paper'

# %%
# - Set data path
dpath = '/opt/skipjack-bigeye-separation/data/'

# %%
# - Set saved out figure path
figpath = '/opt/skipjack-bigeye-separation/python/figures/'

# %% [markdown]
# ### Define fxns

# %%
# %run helper_notebooks/bet_skj_sep_fxns.ipynb

# %% [markdown]
# ### Load WCPFC and ENSO time series data

# %%
# %run helper_notebooks/wcpfc_enso_load_and_calc.ipynb

# %% [markdown]
# ### Create EEZ map mask

# %%
# %run helper_notebooks/create_eez_mask_map.ipynb

# %% [markdown]
# ### Load oceanographic data

# %%
# %run helper_notebooks/load_env_vars.ipynb

# %% [markdown]
# ### Get all vars on WCPFC grid

# %%
dsallvars = bettoskj_cp_tot.to_dataset(name='bettoskj_cp_tot')
dsallvars['skj_cp_tot'] = skj_cp_tot
dsallvars['bet_cp_tot'] = bet_cp_tot
dsallvars['sst'] = sst
dsallvars['temp100'] = temp100
dsallvars['tcd'] = tcd
dsallvars['sss'] = sss
dsallvars['o2100'] = o2100
dsallvars['po2100'] = po2100
dsallvars['thd'] = thd
dsallvars['logchl'] = logchl
dsallvars['mld'] = mld
dsallvars['ssha'] = ssha
dfallvars = dsallvars.to_dataframe()
dfallvars.drop(columns=['depth'], inplace=True)

# %% [markdown]
# ### Compute quotient analyses for SKJ and BET CPUE vs. environmental conditions

# %%
# %run helper_notebooks/compute_qa_bet_skj_cpue.ipynb

# %% [markdown]
# ### Compute temporal correlations btwn SKJ, BET, BET:SKJ CPUE vs. environmental conditions

# %%
# %run helper_notebooks/compute_bet_skj_b2s_vs_env.ipynb

# %% [markdown]
# # Plot figures

# %% [markdown]
# ### Figure 1

# %%
# %run figure_notebooks/figure1_totals.ipynb

# %%
# %run figure_notebooks/figure1_anoms.ipynb

# %% [markdown]
# ### Figure 2

# %%
# %run figure_notebooks/figure2.ipynb

# %% [markdown]
# ### Figure 3

# %%
# %run figure_notebooks/figure3.ipynb

# %% [markdown]
# ### Figure 4

# %%
# %run figure_notebooks/figure4.ipynb

# %% [markdown]
# ### Figure 5

# %%
# %run figure_notebooks/figure5.ipynb

# %% [markdown]
# ### Figure 6

# %%
# %run figure_notebooks/figure6.ipynb

# %% [markdown]
# ### Figure 7

# %%
# %run figure_notebooks/figure7.ipynb

# %% [markdown]
# ### Figure 8

# %%
# %run figure_notebooks/figure8.ipynb

# %% [markdown]
# ### Figure 9

# %%
# %run figure_notebooks/figure9.ipynb

# %% [markdown]
# ### Figure 10

# %% [markdown]
# ### Supplementary Figure 1

# %%
# %run figure_notebooks/suppfigure1.ipynb

# %% [markdown]
# ### Supplementary Figure 2

# %%
# %run figure_notebooks/suppfigure2.ipynb

# %% [markdown]
# ### Supplementary Figures 3-5

# %%
# %run figure_notebooks/suppfigure3_5.ipynb
