# %%
# - CREATE SCATTERPLOTS OF BET CPUE VS. SKJ CPUE, BET:SKJ CPUE VS. SKJ CPUE (anoms)
unitsnow = '[metric tons/set]'
fig,axes = plt.subplots(nrows=2, ncols=3, figsize = (9, 4.5))

# - color by oni
colornow = df_tot_nn['oni']

# - skj and bettoskj vs. bet
sc = axes[0][0].scatter(df_tot_nn['skj_cp_tot_anom'], df_tot_nn['bet_cp_tot_anom'],
                 c=colornow, vmin=-abs(colornow).max(), vmax=abs(colornow).max(),
                 s=10, alpha=0.5, cmap=cm.seismic)
plt.colorbar(sc, ax=axes[0][0], label='ONI [°C]')
axes[0][0].set_xlabel('SKJ CPUE ' + unitsnow)
axes[0][0].set_ylabel('BET CPUE ' + unitsnow)

sc = axes[1][0].scatter(df_tot_nn['skj_cp_tot_anom'], df_tot_nn['bettoskj_cp_tot_anom'],
                 c=colornow, vmin=-abs(colornow).max(), vmax=abs(colornow).max(),
                 s=10, alpha=0.5, cmap=cm.seismic)
plt.colorbar(sc, ax=axes[1][0], label='ONI [°C]')
axes[1][0].set_xlabel('SKJ CPUE ' + unitsnow)
axes[1][0].set_ylabel('BET:SKJ CPUE')

# - skj and bettoskj vs. longitude
sc = axes[0][1].scatter(df_tot_nn['lon'], df_tot_nn['bet_cp_tot_anom'],
                 c=colornow, vmin=-abs(colornow).max(), vmax=abs(colornow).max(),
                 s=10, alpha=0.5, cmap=cm.seismic)
plt.colorbar(sc, ax=axes[0][1], label='ONI [°C]')
axes[0][1].set_xlabel('Longitude')
axes[0][1].set_ylabel('BET CPUE ' + unitsnow)

sc = axes[1][1].scatter(df_tot_nn['lon'], df_tot_nn['bettoskj_cp_tot_anom'],
                 c=colornow, vmin=-abs(colornow).max(), vmax=abs(colornow).max(),
                 s=10, alpha=0.5, cmap=cm.seismic)
plt.colorbar(sc, ax=axes[1][1], label='ONI [°C]')
axes[1][1].set_xlabel('Longitude')
axes[1][1].set_ylabel('BET:SKJ CPUE')

# - skj and bettoskj vs. latitude
sc = axes[0][2].scatter(df_tot_nn['lat'], df_tot_nn['bet_cp_tot_anom'],
                 c=colornow, vmin=-abs(colornow).max(), vmax=abs(colornow).max(),
                 s=10, alpha=0.5, cmap=cm.seismic)
plt.colorbar(sc, ax=axes[0][2], label='ONI [°C]')
axes[0][2].set_xlabel('Latitude')
axes[0][2].set_ylabel('BET CPUE ' + unitsnow)

sc = axes[1][2].scatter(df_tot_nn['lat'],df_tot_nn['bettoskj_cp_tot_anom'],
                 c=colornow, vmin=-abs(colornow).max(), vmax=abs(colornow).max(),
                 s=10, alpha=0.5, cmap=cm.seismic)
plt.colorbar(sc, ax=axes[1][2], label='ONI [°C]')
axes[1][2].set_xlabel('Latitude')
axes[1][2].set_ylabel('BET:SKJ CPUE');

fig.tight_layout()
fig.savefig(figpath + 'mainfig5_bvsscpue_b2svsscpue_anoms_coloredbyoni.png', bbox_inches='tight', pad_inches = 0.05, dpi = 200)
