# %% [markdown]
# ### Compute correl/regress coeff maps

# %%
alphafdr = 0.1

[bvss_cp_tot_anom_rc, bvss_cp_tot_anom_int, bvss_cp_tot_anom_rc_pval,
 bvss_cp_tot_anom_cc, bvss_cp_tot_anom_cc_pval, _
]=gettemprcmap_loop(skj_cp_tot_anom,bet_cp_tot_anom,'bvss_cp_tot')
bvss_cp_tot_anom_rc_ptf = controlfdr2d(bvss_cp_tot_anom_rc_pval,alphafdr)
bvss_cp_tot_anom_cc_ptf = controlfdr2d(bvss_cp_tot_anom_cc_pval,alphafdr)

[b2svss_cp_tot_anom_rc, _, b2svss_cp_tot_anom_rc_pval,
 b2svss_cp_tot_anom_cc, b2svss_cp_tot_anom_cc_pval, _
]=gettemprcmap_loop(skj_cp_tot_anom,bettoskj_cp_tot_anom,'b2svss_cp_tot')
b2svss_cp_tot_anom_rc_ptf = controlfdr2d(b2svss_cp_tot_anom_rc_pval,alphafdr)
b2svss_cp_tot_anom_cc_ptf = controlfdr2d(b2svss_cp_tot_anom_cc_pval,alphafdr)

# %% [markdown]
# ### Plot

# %%
# - Set proj and define axes
fig,axes = plt.subplots(nrows=3, ncols=3, figsize=(16,11),
    subplot_kw={'projection': ccrs.PlateCarree(central_longitude=200)})

# - Make maps pretty
#for ax in axes:
for irow, ax in enumerate(fig.axes):
    exec(open('helper_scripts/create_map_bgs.py').read())

# - Plot mean skj, bet, bet:skj cpue (fig. 1a-c)
unitsnow = '[metric tons/set]'

#ax = axes[irow][icol]
#exec(open("create_map_bgs.py").read())
skj_cp_tot_mean.plot(ax=axes[0][0], transform=ccrs.PlateCarree(),
                     cmap=cm.viridis,
                     cbar_kwargs={'pad': 0.02, 'label': unitsnow});
axes[0][0].set_xlabel(''); axes[0][0].set_ylabel('');
axes[0][0].set_title('Mean SKJ CPUE')

bet_cp_tot_mean.plot(ax=axes[0][1], transform=ccrs.PlateCarree(),
                     cmap=cm.viridis,
                     cbar_kwargs={'pad': 0.02, 'label': unitsnow});
axes[0][1].set_xlabel(''); axes[0][1].set_ylabel('');
axes[0][1].set_title('Mean BET CPUE')

bettoskj_cp_tot_mean.plot(ax=axes[0][2], transform=ccrs.PlateCarree(),
                          cmap=cm.viridis,
                          cbar_kwargs={'pad': 0.02, 'label': ''});
axes[0][2].set_xlabel(''); axes[0][2].set_ylabel('');
axes[0][2].set_title('BET:SKJ CPUE (monthly avg)');

# - Plot bet vs. skj correl, regress, pval (fig. 1d-f)
bvss_cp_tot_anom_cc.plot(ax=axes[1][0], transform=ccrs.PlateCarree(),
                         cmap=cm.seismic,
                         cbar_kwargs={'pad': 0.02, 'label': 'Pearson\'s R'});
[signiflonnow,signiflatnow]=find_where_pval_small(bvss_cp_tot_anom_cc_pval,bvss_cp_tot_anom_cc_ptf)
axes[1][0].scatter(signiflonnow, signiflatnow,
                c='yellow', s=2, transform=ccrs.PlateCarree());
axes[1][0].set_xlabel(''); axes[1][0].set_ylabel('');
axes[1][0].set_title('BET vs. SKJ CPUE anom correlation')

bvss_cp_tot_anom_rc.plot(ax=axes[1][1], transform=ccrs.PlateCarree(),
                         cmap=cm.seismic, vmin=-0.2, vmax=0.2,
                         cbar_kwargs={'pad': 0.02, 'label': 'Linear coefficient', 'extend': 'both'});
[signiflonnow,signiflatnow]=find_where_pval_small(bvss_cp_tot_anom_rc_pval,bvss_cp_tot_anom_rc_ptf)
axes[1][1].scatter(signiflonnow, signiflatnow,
                c='yellow', s=2, transform=ccrs.PlateCarree());
axes[1][1].set_xlabel(''); axes[1][1].set_ylabel('');
axes[1][1].set_title('BET vs. SKJ CPUE anom regression')

cmapnow = cm.viridis
cmapnow.set_over('lightgray')
bvss_cp_tot_anom_rc_pval.plot(ax=axes[1][2], transform=ccrs.PlateCarree(),
                              cmap=cmapnow, vmax=bvss_cp_tot_anom_rc_ptf,
                              cbar_kwargs={'pad': 0.02, 'label': 'p-value', 'extend': 'max'});
axes[1][2].set_xlabel(''); axes[1][2].set_ylabel('');
axes[1][2].set_title('BET vs. SKJ CPUE anom correlation p-value');

# - Plot b:s vs. skj correl, regress, pval (fig. 1g-i)
b2svss_cp_tot_anom_cc.plot(ax=axes[2][0], transform=ccrs.PlateCarree(),
                           cmap=cm.seismic,
                           cbar_kwargs={'pad': 0.02, 'label': 'Pearson\'s R'});
[signiflonnow,signiflatnow]=find_where_pval_small(b2svss_cp_tot_anom_cc_pval,b2svss_cp_tot_anom_cc_ptf)
axes[2][0].scatter(signiflonnow, signiflatnow,
                c='yellow', s=2, transform=ccrs.PlateCarree());
axes[2][0].set_xlabel(''); axes[2][0].set_ylabel('');
axes[2][0].set_title('BET:SKJ vs. SKJ CPUE anom correlation')

b2svss_cp_tot_anom_rc.plot(ax=axes[2][1], transform=ccrs.PlateCarree(),
                           cmap=cm.seismic, vmin=-0.008, vmax=0.008,
                           cbar_kwargs={'pad': 0.02, 'label': 'Linear coefficient [sets/metric ton]', 'extend': 'both'});
[signiflonnow,signiflatnow]=find_where_pval_small(b2svss_cp_tot_anom_rc_pval,b2svss_cp_tot_anom_rc_ptf)
axes[2][1].scatter(signiflonnow, signiflatnow,
                c='yellow', s=2, transform=ccrs.PlateCarree());
axes[2][1].set_xlabel(''); axes[2][1].set_ylabel('');
axes[2][1].set_title('BET:SKJ vs. SKJ CPUE anom regression')

cmapnow = cm.viridis
cmapnow.set_over('lightgray')
b2svss_cp_tot_anom_rc_pval.plot(ax=axes[2][2], transform=ccrs.PlateCarree(),
                                cmap=cmapnow, vmax=b2svss_cp_tot_anom_cc_ptf,
                                cbar_kwargs={'pad': 0.02, 'label': 'p-value', 'extend': 'max'});
axes[2][2].set_xlabel(''); axes[2][2].set_ylabel('');
axes[2][2].set_title('BET:SKJ vs. SKJ CPUE anom correlation p-value');

fig.savefig(figpath + 'mainfig1_anoms.png', bbox_inches='tight', pad_inches = 0, dpi = 200)
