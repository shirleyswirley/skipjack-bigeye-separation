# %% [markdown]
# # Setup workspace, load data, and calculate needed variables

# %% [markdown]
# ### Import packages and setup options/directories

# %%
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
import datetime
import geopandas as gpd
from glob import glob
from matplotlib import cm
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.ticker as mticker
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import regionmask
#from reverse_colormap import reverse_colormap # in python dir
import scipy.stats as stats
from scipy import interpolate as spinterpolate
from shapely.geometry import Polygon
import warnings
import xarray as xr

# %%
# %matplotlib inline

# %%
warnings.filterwarnings('ignore')

# %%
# - See what dir we're in
os.getcwd()
# Out:
# '/opt/skipjack-bigeye-separation/python/bet_skj_separation_paper_v3'

# %%
# - Choose set types you want to analyze
# ...settypes options are: afaddfad, afaddfadlog, allsets,
# unassociated, unassociatedother
# ...catchorcpue options are: catch, CPUE 
settypes = 'afaddfadlog'
catchorcpue = 'CPUE'

# %%
# - Set data path
dpath = '/opt/skipjack-bigeye-separation/data/'

# %%
# - Set saved out figure path
figpath = '/opt/skipjack-bigeye-separation/python/bet_skj_separation_paper_v3/figures_' + settypes + catchorcpue + '/'

# %% [markdown]
# ### Define fxns

# %%
# %run helper_notebooks/bet_skj_sep_fxns.ipynb

# %% [markdown]
# ### Load WCPFC and ENSO time series data

# %%
# %run helper_notebooks/wcpfc_enso_load_and_calc.ipynb

# %% [markdown]
# ### Compute temporal correlations btwn BET and BET:SKJ vs. SKJ CPUE

# %%
# %run helper_notebooks/compute_bet_b2s_vs_skj.ipynb

# %% [markdown]
# ### Create EEZ map mask

# %%
# %run helper_notebooks/create_eez_mask_map.ipynb

# %% [markdown]
# ### Load oceanographic data

# %%
# %run helper_notebooks/env_vars_load_and_calc.ipynb

# %% [markdown]
# ### Put all CPUE and env vars into one xr dataset and onto same grid for ease of use by following calculations

# %%
dsallvars = bettoskj_cp_tot.to_dataset(name='bettoskj_cp_tot')
dsallvars['skj_cp_tot'] = skj_cp_tot
dsallvars['bet_cp_tot'] = bet_cp_tot
dsallvars['sst'] = sst
dsallvars['temp100'] = temp100
dsallvars['tcd'] = tcd
dsallvars['sss'] = sss
dsallvars['o2100'] = o2100
dsallvars['po2100'] = po2100
dsallvars['thd'] = thd
dsallvars['logchl'] = logchl
dsallvars['mld'] = mld
dsallvars['ssha'] = ssha
dsallvars['oni'] = oni
dfallvars = dsallvars.to_dataframe()
dfallvars.drop(columns=['depth'], inplace=True)
dfallvars.reset_index(inplace=True)

# %% [markdown]
# ### Compute quotient analyses for SKJ and BET CPUE vs. environmental conditions

# %%
#%%script false --no-raise-error
# %run helper_notebooks/compute_qa_bet_skj_cpue.ipynb

# %% [markdown]
# ### Compute temporal correlations btwn SKJ, BET, BET:SKJ CPUE vs. environmental conditions

# %%
# %run helper_notebooks/compute_bet_skj_b2s_vs_env.ipynb

# %% [markdown]
# # Plot main figures

# %% [markdown]
# ### Figure 1

# %%
# %run figure_notebooks/fig1.ipynb

# %% [markdown]
# ### Figure 2

# %%
# %run figure_notebooks/fig2.ipynb

# %% [markdown]
# ### Figure 3

# %%
mapvarnow = 'bettoskj'
# %run figure_notebooks/fig3.ipynb

# %% [markdown]
# ### Figure 4

# %%
mapvarnow = 'bettoskj'
# %run figure_notebooks/fig4_suppfig4_5.ipynb

# %% [markdown]
# ### Figure 5

# %%
# %run figure_notebooks/fig5.ipynb
# Out:
# SKJ CPUE within PNA EEZs left medians, means:
# [4.63497519493103, 23.337682723999023, 15.774703979492188, 18.68938446044922, 24.37333583831787, 29.561219215393066, 30.01768684387207, 27.912531852722168, 29.835572242736816, 35.81155014038086]
# [7.0468388, 24.65096, 17.524149, 20.517653, 24.621552, 30.315954, 29.988325, 33.601543, 39.159378, 41.50945]
# middle medians, means:
# [5.184481620788574, 24.151411056518555, 16.83989143371582, 20.273736000061035, 28.22077178955078, 31.968564987182617, 31.12686538696289, 29.770282745361328, 25.23531150817871, 35.81155014038086]
# [6.997404, 25.957344, 19.251524, 23.043354, 29.586693, 32.290806, 33.72428, 37.15391, 35.369305, 40.3106]
# right medians, means:
# [5.708381652832031, 24.51101303100586, 17.13985538482666, 22.069982528686523, 33.996633529663086, 29.06793212890625, 36.38367462158203, 30.024978637695312, 24.155363082885742, nan]
# [6.5484176, 26.102644, 19.4881, 25.622587, 34.15958, 31.040567, 41.957428, 34.02878, 28.029074, nan]
# SKJ CPUE boxplot # of months in obs:
# PLW 192 723 211
# FSM 248 1049 277
# PNG 368 1531 424
# SLB 109 500 157
# NRU 74 260 70
# MHL 48 204 63
# KIR-G 170 574 129
# TUV 54 175 59
# KIR-P 36 74 10
# KIR-L 35 39 0
# BET CPUE within PNA EEZs left medians, means:
# [0.23507440090179443, 2.8378719091415405, 2.0584118366241455, 1.5779411792755127, 2.785096764564514, 3.236175775527954, 2.7301125526428223, 1.741391897201538, 3.8956139087677, 2.987851142883301]
# [0.3796874, 3.2484658, 2.4382954, 2.062346, 3.150112, 3.2275603, 3.0154831, 2.0918672, 4.278219, 4.752581]
# middle medians, means:
# [0.2511555552482605, 2.4366369247436523, 1.7251778841018677, 1.4781893491744995, 3.2969926595687866, 3.447550654411316, 3.145790934562683, 1.9523817300796509, 4.131932497024536, 2.987851142883301]
# [0.37211624, 2.6831656, 2.070173, 1.7292686, 3.7004788, 3.6650982, 3.747676, 2.3180068, 4.4932323, 5.2565565]
# right medians, means:
# [0.23927778005599976, 2.441728115081787, 1.6380029916763306, 1.7081201076507568, 4.261855125427246, 3.4514882564544678, 4.784046649932861, 3.087163209915161, 6.798277854919434, nan]
# [0.37516588, 2.6873462, 1.9520268, 1.8710759, 4.6475754, 3.6681278, 5.6518536, 3.211423, 5.919606, nan]
# BET CPUE boxplot # of months in obs:
# PLW 192 723 211
# FSM 248 1049 277
# PNG 368 1531 424
# SLB 109 500 157
# NRU 74 260 70
# MHL 48 204 63
# KIR-G 170 574 129
# TUV 54 175 59
# KIR-P 36 74 10
# KIR-L 35 39 0
# BET:SKJ CPUE within PNA EEZs left medians, means:
# [0.04760746285319328, 0.12733527272939682, 0.11776145175099373, 0.08372467011213303, 0.1183551549911499, 0.11733178049325943, 0.09107139706611633, 0.05366599187254906, 0.13454125076532364, 0.135482057929039]
# [0.05676352, 0.16268241, 0.16180037, 0.118665434, 0.15809132, 0.13681774, 0.12201352, 0.09258179, 0.1504586, 0.15319173]
# middle medians, means:
# [0.04505915194749832, 0.10647771507501602, 0.10181944072246552, 0.061518922448158264, 0.12268810719251633, 0.11517499387264252, 0.1108747124671936, 0.05843324027955532, 0.13729217648506165, 0.135482057929039]
# [0.059004027, 0.11838432, 0.1243853, 0.090102695, 0.14314456, 0.12724444, 0.12310888, 0.08718597, 0.17299078, 0.16040768]
# right medians, means:
# [0.05046578496694565, 0.1075768992304802, 0.09148121252655983, 0.05905412882566452, 0.1684083193540573, 0.1187986433506012, 0.13486404716968536, 0.10106085985898972, 0.24095353484153748, nan]
# [0.07167874, 0.10760792, 0.11577927, 0.09835281, 0.15598643, 0.1307596, 0.14531523, 0.1115317, 0.24029092, nan]
# BET:SKJ CPUE boxplot # of months in obs:
# PLW 192 723 211
# FSM 248 1047 275
# PNG 368 1529 424
# SLB 109 500 157
# NRU 73 259 70
# MHL 48 202 61
# KIR-G 170 568 129
# TUV 53 174 59
# KIR-P 36 73 10
# KIR-L 34 38 0

# %% [markdown]
# ### Figure 6

# %%
# %run figure_notebooks/fig6.ipynb
# Out:
# SKJ CPUE within PNA EEZs win medians, means:
# [5.09328293800354, 27.028385162353516, 19.008813858032227, 23.79523277282715, 26.22946834564209, 32.911848068237305, 30.471684455871582, 32.26505756378174, 31.273935317993164, 54.74898910522461]
# [7.2308993, 29.572615, 20.997187, 26.045872, 28.50137, 30.89649, 31.773455, 37.823307, 37.150684, 51.08183]
# spr medians, means:
# [4.974183082580566, 28.91399097442627, 17.783205032348633, 21.81779670715332, 34.847877502441406, 35.7360782623291, 31.36639976501465, 25.683504104614258, 35.84394454956055, nan]
# [7.1711197, 31.292912, 20.054327, 23.210203, 34.151283, 39.044308, 31.977781, 26.966288, 42.375526, nan]
# sum medians, means:
# [5.600501775741577, 19.063847541809082, 13.177585124969482, 15.25151777267456, 28.193889617919922, 27.30126953125, 30.2703914642334, 22.66754913330078, 20.094507217407227, 26.913728713989258]
# [6.5877724, 20.726978, 14.573561, 15.455522, 28.27091, 30.594534, 33.292625, 23.294493, 26.50341, 41.522053]
# aut medians, means:
# [5.310796737670898, 21.821849822998047, 16.352590560913086, 19.31815528869629, 24.791709899902344, 31.629815101623535, 33.39260292053223, 35.31234359741211, 35.3849983215332, 32.588040351867676]
# [7.0207224, 23.356133, 19.94552, 22.502266, 27.946192, 30.511795, 36.789387, 52.780975, 38.5539, 37.52959]
# SKJ CPUE boxplot # of months in obs:
# PLW 182 169 186 186
# FSM 193 294 306 256
# PNG 451 391 294 395
# SLB 185 133 68 114
# NRU 72 59 63 66
# MHL 42 40 66 56
# KIR-G 116 119 173 166
# TUV 48 45 29 53
# KIR-P 14 16 23 21
# KIR-L 6 0 9 22
# BET CPUE within PNA EEZs win medians, means:
# BET:SKJ CPUE boxplot # of months in obs:
# PLW 182 169 186 186
# FSM 193 294 305 255
# PNG 451 391 293 394
# SLB 185 133 68 114
# NRU 72 59 63 65
# MHL 41 40 66 55
# KIR-G 116 115 172 165
# TUV 48 45 28 53
# KIR-P 14 16 22 21
# KIR-L 6 0 8 22

# %% [markdown]
# ### Figure 7

# %%
# %run figure_notebooks/fig7.ipynb

# %% [markdown]
# ### Figure 8

# %%
# %run figure_notebooks/fig8.ipynb

# %% [markdown]
# # Plot supp figures

# %% [markdown]
# ### Supplementary Figure 2

# %%
# %run figure_notebooks/suppfig2.ipynb

# %% [markdown]
# ### Supplementary Figure 3

# %%
# %run figure_notebooks/suppfig3.ipynb
# Out:
# ['skj_cp_tot', 'bet_cp_tot', 'sss', 'sst', 'temp100', 'tcd', 'o2100', 'po2100', 'thd', 'logchl', 'mld', 'ssha']
# # of monthly mean data pts overlapping w/ skj_cp_tot:
# lat: 9842
# time: 9842
# bettoskj_cp_tot: 9819
# skj_cp_tot: 9842
# bet_cp_tot: 9842
# sst: 7079
# temp100: 7267
# tcd: 6926
# sss: 5220
# o2100: 627
# po2100: 580
# thd: 591
# logchl: 6605
# mld: 7395
# ssha: 7936
# oni: 9842
# # of monthly mean data pts overlapping w/ bet_cp_tot:
# lat: 9842
# lon: 9842
# bettoskj_cp_tot: 9819
# skj_cp_tot: 9842
# bet_cp_tot: 9842
# sst: 7079
# temp100: 7267
# tcd: 6926
# sss: 5220
# o2100: 627
# po2100: 580
# thd: 591
# logchl: 6605
# mld: 7395
# ssha: 7936
# oni: 9842
# # of monthly mean data pts overlapping w/ bettoskj_cp_tot:
# lon: 9819
# time: 9819
# bettoskj_cp_tot: 9819
# skj_cp_tot: 9819
# bet_cp_tot: 9819
# sst: 7059
# temp100: 7247
# tcd: 6907
# sss: 5206
# o2100: 626
# po2100: 579
# thd: 590
# logchl: 6593
# mld: 7379
# ssha: 7921
# oni: 9819

# %% [markdown]
# ### Supplementary Figures 4-5

# %%
mapvarnow = 'skj'
# %run figure_notebooks/fig4_suppfig4_5.ipynb

# %%
mapvarnow = 'bet'
# %run figure_notebooks/fig4_suppfig4_5.ipynb

# %% [markdown]
# ### Supplementary Figures 6-8

# %%
# %run figure_notebooks/suppfig6_8.ipynb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /opt/skipjack-bigeye-separation/python/bet_skj_separation_paper_v3/figure_notebooks/suppfig6_8.ipynb in <module>
#       6 pvsnow = nseas*nvars*[None]
#       7 ptfsnow = nseas*nvars*[None]
# ----> 8 if totanomnow=='anom':
#       9     cmnow = cm.PuOr
#      10     stipedgedkcolnow = 'darkslategray'
#
# NameError: name 'totanomnow' is not defined

# %% [markdown]
# ### Supplementary Figures 9-10

# %%
# %run figure_notebooks/suppfig9_10.ipynb

# %% [markdown]
# ### Supplementary Figures 11-13

# %%
# %run figure_notebooks/suppfig11_13.ipynb

# %% [markdown]
# ### Supplementary Figure 14

# %%
# %run figure_notebooks/suppfig14.ipynb
